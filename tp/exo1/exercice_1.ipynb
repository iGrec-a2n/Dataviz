# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercice 1
# #### Affichage des 5 premières lignes

# %%
games = pd.read_csv("../../data/flipper_games.csv");

games.head()
# Out:
#              timestamp player_id machine_id       machine_type arcade_zone  \
# 0  2026-02-03 10:00:00      P001        F17  electromechanical          C3
# 1  2026-02-03 10:00:00      P221        F04        solid_state          D1
# 2  2026-02-03 10:05:00      P034        F13            digital          C1
# 3  2026-02-03 10:05:00      P007        F06        solid_state          D1
# 4  2026-02-03 10:05:00      P009        F16  electromechanical          A2
#
#    game_mode  game_duration_s  pause_s  tilt_risk_pct  ball_speed_mps  \
# 0   speedrun              188        0          39.32           1.154
# 1  multiball              218       23          76.10           1.002
# 2    classic              143       21           5.86           0.965
# 3  multiball              319       41          47.16           1.054
# 4    classic              175       33          60.06           0.934
#
#    playfield_temp_c error_code game_status  incident_label
# ...

# %% [markdown]
# #### Affichage des types des colonnes

# %%
games.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5409 entries, 0 to 5408
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         5409 non-null   str
#  1   player_id         5409 non-null   str
#  2   machine_id        5409 non-null   str
#  3   machine_type      5409 non-null   str
#  4   arcade_zone       5409 non-null   str
#  5   game_mode         5409 non-null   str
#  6   game_duration_s   5409 non-null   int64
#  7   pause_s           5409 non-null   int64
#  8   tilt_risk_pct     5409 non-null   float64
#  9   ball_speed_mps    5409 non-null   float64
#  10  playfield_temp_c  5409 non-null   float64
#  11  error_code        279 non-null    str
#  12  game_status       5409 non-null   str
#  13  incident_label    5409 non-null   int64
# dtypes: float64(3), int64(3), str(8)
# memory usage: 591.7 KB

# %% [markdown]
# #### Affichage du nombre de lignes et de colonnes

# %%
print("le dataset contient", games.shape[0], "lignes et", games.shape[1], "colonnes")
# Out:
# le dataset contient 5409 lignes et 14 colonnes

# %% [markdown]
# #### Affichage du nombre de joueurs uniques

# %%
number_of_unique_player = games["player_id"].nunique()

print("Il y a", number_of_unique_player, "joueurs")
# Out:
# 260
