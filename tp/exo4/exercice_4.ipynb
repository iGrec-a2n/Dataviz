# %% [markdown]
# # Exercie 4 - Visualisation Barplot

# %%
import panda as pd
import matplotlib.pyplot as plt
flipper=pd.read_csv('../../data/flipper.csv')

# %% [markdown]
# ## 1. Barplot de Taux d'erreur / zone_kpi

# %%
zone_err = games_clean.groupby("arcade_zone", as_index=False).agg(
    is_error=("is_error", "mean")
).sort_values("is_error", ascending=False)

sns.barplot(data=zone_err, x="arcade_zone", y="is_error", color="red")
plt.title("Taux d'erreur moyen par zone d'arcade")
plt.xlabel("Zone d'arcade")
plt.ylabel("Taux d'erreur")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
